# %% [markdown]
# # <center> Differential_Forms-GUI-Dashboard </center>

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from plotting_stacks import*
# Out:
# Time:  1.2402062379999998

# %%
import sys
_2forms_PATH = '_2_forms_and_ visualisations'
sys.path.insert(1, _2forms_PATH)
from Visualising_2forms_on_R2 import*
# Out:
#  the resulting 2 form is :
# [[' + -y*sin(x) - (x*cos(y))']]
#
#
# the matrix of derrivatives was:
# [['0*x' ' - (x*cos(y))']
#  [' + -y*sin(x)' '0*x']]
#
#
# Time to run:  2.520360974000001

# %%
from _2forms_on_Rm import*
# Out:
#  the resulting 2 form is :
# [[' + 8*x*z - (x*z)']
#  [' + y*z*cos(x) - (x*y)']
#  [' + z*sin(x) - (4*x**2)']]
#
#
# the matrix of derrivatives was:
# [['0*x' ' - (x*z)' ' - (x*y)']
#  [' + 8*x*z' '0*x' ' - (4*x**2)']
#  [' + y*z*cos(x)' ' + z*sin(x)' '0*x']]
#
#
# Time to run:  0.02837848400000098

# %%
from shapes_on_grid_Visulaise_2_forms import
# Out:
#  the resulting 2 form is :
# [[' + 8*x*z - (x*z)']
#  [' + y*z*cos(x) - (x*y)']
#  [' + z*sin(x) - (4*x**2)']]
#
#
# the matrix of derrivatives was:
# [['0*x' ' - (x*z)' ' - (x*y)']
#  [' + 8*x*z' '0*x' ' - (4*x**2)']
#  [' + y*z*cos(x)' ' + z*sin(x)' '0*x']]
#
#
# Time to run:  0.059290947999997456

# %%
"This opens GUI in a separate window"

from plotting_stacks_GUI import*
